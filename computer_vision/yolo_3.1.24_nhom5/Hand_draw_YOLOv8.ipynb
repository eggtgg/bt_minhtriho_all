# %% [markdown]
# <a href="https://colab.research.google.com/github/eggtgg/bt_minhtriho_all/blob/main/computer_vision/yolo_3.1.24_nhom5/Hand_draw_YOLOv8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.232 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 26.3/78.2 GB disk)

# %%
# !gdown 1uiFH0x_UVSIAZz9guwVrF3yMGWKAKsHh
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1uiFH0x_UVSIAZz9guwVrF3yMGWKAKsHh
# To: /content/handdraw.rar
# 100% 7.27M/7.27M [00:00<00:00, 68.7MB/s]

# %%
# !pip install unrar
# !unrar x /content/handdraw.rar

# %%
# Train YOLOv8n on COCO8 for 3 epochs
# !yolo train model=yolov8n.pt data=data.yaml epochs=200 imgsz=640
# Out:
# Ultralytics YOLOv8.0.232 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo predict model=/content/runs/detect/train2/weights/best.pt source='/content/handdraw.mp4'
# Out:
# Ultralytics YOLOv8.0.232 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3006233 parameters, 0 gradients, 8.1 GFLOPs
#
# WARNING ⚠️ NMS time limit 0.550s exceeded
# video 1/1 (1/550) /content/handdraw.mp4: 384x640 1 rectangle, 1 ellipse, 1 triangle, 191.8ms
# video 1/1 (2/550) /content/handdraw.mp4: 384x640 1 rectangle, 1 ellipse, 1 triangle, 9.8ms
# video 1/1 (3/550) /content/handdraw.mp4: 384x640 1 rectangle, 1 ellipse, 1 triangle, 8.6ms
# video 1/1 (4/550) /content/handdraw.mp4: 384x640 1 rectangle, 1 ellipse, 1 triangle, 10.1ms
# video 1/1 (5/550) /content/handdraw.mp4: 384x640 1 rectangle, 1 ellipse, 1 triangle, 8.7ms
# video 1/1 (6/550) /content/handdraw.mp4: 384x640 1 rectangle, 1 ellipse, 1 triangle, 7.9ms
# video 1/1 (7/550) /content/handdraw.mp4: 384x640 1 rectangle, 1 ellipse, 1 triangle, 7.8ms
# video 1/1 (8/550) /content/handdraw.mp4: 384x640 1 rectangle, 1 ellipse, 1 triangle, 8.3ms
# ...

# %%
import locale
locale.getpreferredencoding = lambda: "UTF-8"

# %%
# !zip -r /content/run.zip /content/runs
# Out:
#   adding: content/runs/ (stored 0%)
#   adding: content/runs/detect/ (stored 0%)
#   adding: content/runs/detect/predict/ (stored 0%)
#   adding: content/runs/detect/predict/eRkIOefQRI4_si_nl3tFjZfIYu4_ice.avi (deflated 4%)
#   adding: content/runs/detect/train/ (stored 0%)
#   adding: content/runs/detect/train/labels.jpg (deflated 26%)
#   adding: content/runs/detect/train/train_batch2.jpg (deflated 25%)
#   adding: content/runs/detect/train/events.out.tfevents.1704187282.69d3034be7bf.1596.0 (deflated 94%)
#   adding: content/runs/detect/train/labels_correlogram.jpg (deflated 39%)
#   adding: content/runs/detect/train/weights/ (stored 0%)
#   adding: content/runs/detect/train/weights/best.pt (deflated 8%)
#   adding: content/runs/detect/train/weights/last.pt (deflated 8%)
#   adding: content/runs/detect/train/train_batch0.jpg (deflated 21%)
#   adding: content/runs/detect/train/train_batch1.jpg (deflated 22%)
#   adding: content/runs/detect/train/results.csv (deflated 71%)
# ...

# %%
from google.colab import files
files.download("/content/run.zip")

# %%
from ultralytics.utils.benchmarks import benchmark

# Benchmark on GPU
benchmark(model='/content/runs/detect/train2/weights/best.pt', data='data.yaml', imgsz=640, half=False, device=0)
# Out:
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 30.3/78.2 GB disk)
#
# Benchmarks complete for best.pt on data.yaml at imgsz=640 (94.56s)
#                    Format Status❔  Size (MB)  metrics/mAP50-95(B)  Inference time (ms/im)
# 0                 PyTorch       ✅        6.0               0.9514                   11.50
# 1             TorchScript       ✅       11.9               0.9410                    9.66
# 2                    ONNX       ✅       11.7               0.9410                  156.50
# 3                OpenVINO       ❌        0.0                  NaN                     NaN
# 4                TensorRT       ✅       15.1               0.9410                    3.43
# 5                  CoreML       ❌        0.0                  NaN                     NaN
# 6   TensorFlow SavedModel       ❌        0.0                  NaN                     NaN
# 7     TensorFlow GraphDef       ❌        0.0                  NaN                     NaN
# ...
